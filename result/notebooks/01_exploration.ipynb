# %% [markdown]
# # Animetor Eval — 初期探索
#
# データソースの確認とグラフ構造の初期可視化。

# %%
import networkx as nx
import pandas as pd

from src.utils.config import RAW_DIR, PROCESSED_DIR

# %% [markdown]
# ## データ読み込み
#
# TODO: スクレイピング完了後にデータを読み込む
